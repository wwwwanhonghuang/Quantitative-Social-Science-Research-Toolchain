# %%
import requests
import pprint

# %%
# some useful functions and variables
works_api_url = 'https://api.crossref.org/v1/works'

def get_works(params:dict, filters = {}) -> tuple[dict, int]:
    '''
    Query the Crossref works endpoint and return json. In case of a problem returning
    the results, an empty dictionary is returned.

    See https://api.crossref.org for API documentation and information on available parameters

    parameters
    ----------
    params: dict
        query parameters for the Crossref works API, e.g. {'rows': 1, 'mailto':'myemail@demo.org'}
    filters: dict
        query filters e.g. {'from-pub-date': '2024-01-01', 'type': 'journal-article'}

    returns:
    dict:
        json output of the API as a dictionary
        the list of metadata records is in d['message']['items']
    int:
        the html status code of the query, e.g.
        200 for a successful query
        4XX for a user error
        5XX for a server error
    '''

    # reformat and add filters to the query parameters if used
    if len(list(filters.keys())) > 0:
        params['filter'] = filters_to_params(filters)

    # make the query
    r = requests.get(works_api_url, params=params)

    # get the json output from the API response
    if r.status_code == 200:
        js = r.json()
    else:
        # something went wrong, print the response and return an empty dictionary
        print(r.text)
        js = {}
    return js, r.status_code


def filters_to_params(filters:dict) -> str:
    ''' Set the filters parameter for the Crossref works API using a dictionary

    parameters
    ----------
    filters: dict
        filters for the Crossref works endpoint, e.g. {'from-pub-date': '2024-01-01', 'type': 'journal-article'}

    returns
    -------
    str:
        the filters expressed as a string, e.g. 'from-pub-date:2024-01-01,type:journal-article'
        This should be added to the query parameters dictionary with the key 'filter'

    '''

    # create an empty string for the filter values
    fval = ''
    # add each filter key and value to the string
    for f in filters:
        fval += str(f) + ':' + str(filters[f]) + ','
    fval = fval[:-1] # removing trailing comma

    return fval


def save_to_json(data:dict, fname:str) -> None:
    ''' save a dictionary as a json file '''
    with open(fname, 'w') as f:
        json.dump(data, f, indent=2)

# %%
# set up the parameters
query_params = {
    'rows': 5
}

# put the filters into another dictionary
filters = {
    'from-pub-date': '2023-10-01',
    'is-update': 1
}

# let's run the function we defined above
js, status = get_works(query_params, filters)

# %%
pprint.pprint(js)
# Out:
# {'message': {'facets': {},
#              'items': [{'DOI': '10.2991/978-94-6463-520-1_18',
#                         'ISBN': ['9789464635195', '9789464635201'],
#                         'ISSN': ['2731-7889', '2352-541X'],
#                         'URL': 'https://doi.org/10.2991/978-94-6463-520-1_18',
#                         'assertion': [{'group': {'label': 'Chapter History',
#                                                  'name': 'ChapterHistory'},
#                                        'label': 'First Online',
#                                        'name': 'first_online',
#                                        'order': 1,
#                                        'value': '4 December 2024'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Acronym',
#                                        'name': 'conference_acronym',
#                                        'order': 1,
#                                        'value': 'ISST'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Name',
#                                        'name': 'conference_name',
#                                        'order': 2,
#                                        'value': 'International Seminar on '
#                                                 'Science and Technology'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference City',
#                                        'name': 'conference_city',
#                                        'order': 3,
#                                        'value': 'Palu'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Country',
#                                        'name': 'conference_country',
#                                        'order': 4,
#                                        'value': 'Indonesia'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Year',
#                                        'name': 'conference_year',
#                                        'order': 5,
#                                        'value': '2023'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Start Date',
#                                        'name': 'conference_start_date',
#                                        'order': 7,
#                                        'value': '8 December 2023'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference End Date',
#                                        'name': 'conference_end_date',
#                                        'order': 8,
#                                        'value': '9 December 2023'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Number',
#                                        'name': 'conference_number',
#                                        'order': 9,
#                                        'value': '5'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference ID',
#                                        'name': 'conference_id',
#                                        'order': 10,
#                                        'value': 'isst2023'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference URL',
#                                        'name': 'conference_url',
#                                        'order': 11,
#                                        'value': 'https://isst5.fmipa.untad.ac.id/'}],
#                         'author': [{'affiliation': [],
#                                     'family': 'Yuyun',
#                                     'given': 'Yonelian',
#                                     'sequence': 'first'},
#                                    {'affiliation': [],
#                                     'family': 'Rasyiid',
#                                     'given': 'Mustafid',
#                                     'sequence': 'additional'},
#                                    {'affiliation': [],
#                                     'family': 'Zubair',
#                                     'given': 'Muhammad Sulaiman',
#                                     'sequence': 'additional'},
#                                    {'affiliation': [],
#                                     'family': 'Sesa',
#                                     'given': 'Elisa',
#                                     'sequence': 'additional'}],
#                         'container-title': ['Advances in Physics Research',
#                                             'Proceedings of the 5th '
#                                             'International Seminar on Science '
#                                             'and Technology (ISST 2023)'],
#                         'content-domain': {'crossmark-restriction': False,
#                                            'domain': ['link.springer.com']},
#                         'created': {'date-parts': [[2024, 12, 5]],
#                                     'date-time': '2024-12-05T14:47:22Z',
#                                     'timestamp': 1733410042000},
#                         'deposited': {'date-parts': [[2024, 12, 5]],
#                                       'date-time': '2024-12-05T15:03:25Z',
#                                       'timestamp': 1733411005000},
#                         'indexed': {'date-parts': [[2025, 3, 28]],
#                                     'date-time': '2025-03-28T00:16:27Z',
#                                     'timestamp': 1743120987763,
#                                     'version': '3.40.3'},
#                         'is-referenced-by-count': 0,
#                         'isbn-type': [{'type': 'print',
#                                        'value': '9789464635195'},
#                                       {'type': 'electronic',
#                                        'value': '9789464635201'}],
#                         'issn-type': [{'type': 'print', 'value': '2731-7889'},
#                                       {'type': 'electronic',
#                                        'value': '2352-541X'}],
#                         'issued': {'date-parts': [[2024]]},
#                         'language': 'en',
#                         'license': [{'URL': 'https://creativecommons.org/licenses/by-nc/4.0',
#                                      'content-version': 'tdm',
#                                      'delay-in-days': 0,
#                                      'start': {'date-parts': [[2024, 1, 1]],
#                                                'date-time': '2024-01-01T00:00:00Z',
#                                                'timestamp': 1704067200000}},
#                                     {'URL': 'https://creativecommons.org/licenses/by-nc/4.0',
#                                      'content-version': 'vor',
#                                      'delay-in-days': 338,
#                                      'start': {'date-parts': [[2024, 12, 4]],
#                                                'date-time': '2024-12-04T00:00:00Z',
#                                                'timestamp': 1733270400000}}],
#                         'member': '1574',
#                         'page': 'C1-C1',
#                         'prefix': '10.2991',
#                         'published': {'date-parts': [[2024]]},
#                         'published-online': {'date-parts': [[2024, 12, 4]]},
#                         'published-print': {'date-parts': [[2024]]},
#                         'publisher': 'Atlantis Press International BV',
#                         'publisher-location': 'Dordrecht',
#                         'reference-count': 0,
#                         'references-count': 0,
#                         'resource': {'primary': {'URL': 'https://www.atlantis-press.com/doi/10.2991/978-94-6463-520-1_18'}},
#                         'score': 0.0,
#                         'source': 'Crossref',
#                         'title': ['Correction to: Proceedings of the 5th '
#                                   'International Seminar on Science and '
#                                   'Technology (ISST 2023)'],
#                         'type': 'book-chapter',
#                         'update-policy': 'https://doi.org/10.1007/springer_crossmark_policy',
#                         'update-to': [{'DOI': '10.2991/978-94-6463-520-1',
#                                        'label': 'Correction',
#                                        'source': 'publisher',
#                                        'type': 'correction',
#                                        'updated': {'date-parts': [[2024,
#                                                                    12,
#                                                                    4]],
#                                                    'date-time': '2024-12-04T00:00:00Z',
#                                                    'timestamp': 1733270400000}}]},
#                        {'DOI': '10.1007/978-3-031-80778-7_29',
#                         'ISBN': ['9783031807770', '9783031807787'],
#                         'ISSN': ['1865-0929', '1865-0937'],
#                         'URL': 'https://doi.org/10.1007/978-3-031-80778-7_29',
#                         'assertion': [{'group': {'label': 'Chapter History',
#                                                  'name': 'ChapterHistory'},
#                                        'label': 'First Online',
#                                        'name': 'first_online',
#                                        'order': 1,
#                                        'value': '23 December 2024'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Acronym',
#                                        'name': 'conference_acronym',
#                                        'order': 1,
#                                        'value': 'ICBDA'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Name',
#                                        'name': 'conference_name',
#                                        'order': 2,
#                                        'value': 'International Conference on '
#                                                 'Business Data Analytics'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference City',
#                                        'name': 'conference_city',
#                                        'order': 3,
#                                        'value': 'Dehradun'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Country',
#                                        'name': 'conference_country',
#                                        'order': 4,
#                                        'value': 'India'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Year',
#                                        'name': 'conference_year',
#                                        'order': 5,
#                                        'value': '2023'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Start Date',
#                                        'name': 'conference_start_date',
#                                        'order': 7,
#                                        'value': '7 December 2023'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference End Date',
#                                        'name': 'conference_end_date',
#                                        'order': 8,
#                                        'value': '8 December 2023'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference Number',
#                                        'name': 'conference_number',
#                                        'order': 9,
#                                        'value': '2'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference ID',
#                                        'name': 'conference_id',
#                                        'order': 10,
#                                        'value': 'icbda2023'},
#                                       {'group': {'label': 'Conference '
#                                                           'Information',
#                                                  'name': 'ConferenceInfo'},
#                                        'label': 'Conference URL',
#                                        'name': 'conference_url',
#                                        'order': 11,
#                                        'value': 'https://icbda2023.uudoon.in/'},
#                                       {'label': 'Free to read',
#                                        'name': 'free',
#                                        'value': 'This content has been made '
#                                                 'available to all.'}],
#                         'author': [{'affiliation': [],
#                                     'family': 'Ahmad',
#                                     'given': 'Vasim',
#                                     'sequence': 'first'},
#                                    {'affiliation': [],
#                                     'family': 'Goyal',
#                                     'given': 'Lalit',
#                                     'sequence': 'additional'},
#                                    {'affiliation': [],
#                                     'family': 'Walia',
#                                     'given': 'Arpit',
#                                     'sequence': 'additional'},
#                                    {'affiliation': [],
#                                     'family': 'Arora',
#                                     'given': 'Jigyasha',
#                                     'sequence': 'additional'}],
#                         'container-title': ['Communications in Computer and '
#                                             'Information Science',
#                                             'Business Data Analytics'],
#                         'content-domain': {'crossmark-restriction': False,
#                                            'domain': ['link.springer.com']},
#                         'created': {'date-parts': [[2025, 3, 3]],
#                                     'date-time': '2025-03-03T11:19:04Z',
#                                     'timestamp': 1741000744000},
#                         'deposited': {'date-parts': [[2025, 3, 3]],
#                                       'date-time': '2025-03-03T11:19:06Z',
#                                       'timestamp': 1741000746000},
#                         'indexed': {'date-parts': [[2025, 3, 28]],
#                                     'date-time': '2025-03-28T04:00:02Z',
#                                     'timestamp': 1743134402071,
#                                     'version': '3.40.3'},
#                         'is-referenced-by-count': 0,
#                         'isbn-type': [{'type': 'print',
#                                        'value': '9783031807770'},
#                                       {'type': 'electronic',
#                                        'value': '9783031807787'}],
#                         'issn-type': [{'type': 'print', 'value': '1865-0929'},
#                                       {'type': 'electronic',
#                                        'value': '1865-0937'}],
#                         'issued': {'date-parts': [[2024, 12, 23]]},
#                         'language': 'en',
#                         'license': [{'URL': 'https://www.springernature.com/gp/researchers/text-and-data-mining',
#                                      'content-version': 'tdm',
#                                      'delay-in-days': 0,
#                                      'start': {'date-parts': [[2024, 12, 23]],
#                                                'date-time': '2024-12-23T00:00:00Z',
#                                                'timestamp': 1734912000000}},
#                                     {'URL': 'https://www.springernature.com/gp/researchers/text-and-data-mining',
#                                      'content-version': 'vor',
#                                      'delay-in-days': 0,
#                                      'start': {'date-parts': [[2024, 12, 23]],
#                                                'date-time': '2024-12-23T00:00:00Z',
#                                                'timestamp': 1734912000000}}],
#                         'link': [{'URL': 'https://link.springer.com/content/pdf/10.1007/978-3-031-80778-7_29',
#                                   'content-type': 'unspecified',
#                                   'content-version': 'vor',
#                                   'intended-application': 'similarity-checking'}],
#                         'member': '297',
#                         'page': 'C1-C1',
#                         'prefix': '10.1007',
#                         'published': {'date-parts': [[2024, 12, 23]]},
#                         'published-online': {'date-parts': [[2024, 12, 23]]},
#                         'published-print': {'date-parts': [[2025]]},
#                         'publisher': 'Springer Nature Switzerland',
#                         'publisher-location': 'Cham',
#                         'reference-count': 0,
#                         'references-count': 0,
#                         'resource': {'primary': {'URL': 'https://link.springer.com/10.1007/978-3-031-80778-7_29'}},
#                         'score': 0.0,
#                         'source': 'Crossref',
#                         'title': ['Correction to: Integrating Computer Vision '
#                                   'and Pattern Recognition in Fraud Detection '
#                                   'for Financial Accounts'],
#                         'type': 'book-chapter',
#                         'update-policy': 'https://doi.org/10.1007/springer_crossmark_policy',
#                         'update-to': [{'DOI': '10.1007/978-3-031-80778-7_2',
#                                        'label': 'Correction',
#                                        'source': 'publisher',
#                                        'type': 'correction',
#                                        'updated': {'date-parts': [[2024,
#                                                                    12,
#                                                                    23]],
#                                                    'date-time': '2024-12-23T00:00:00Z',
#                                                    'timestamp': 1734912000000}}]},
#                        {'DOI': '10.1017/s0007114524002411',
#                         'ISSN': ['0007-1145', '1475-2662'],
#                         'URL': 'https://doi.org/10.1017/s0007114524002411',
#                         'alternative-id': ['S0007114524002411'],
#                         'assertion': [{'group': {'label': 'Copyright and '
#                                                           'Licensing',
#                                                  'name': 'copyright_and_licensing'},
#                                        'label': 'Copyright',
#                                        'name': 'copyright',
#                                        'value': '© The Author(s), 2024. '
#                                                 'Published by Cambridge '
#                                                 'University Press on behalf of '
#                                                 'The Nutrition Society'}],
#                         'author': [{'affiliation': [],
#                                     'family': 'Kanerva',
#                                     'given': 'Noora',
#                                     'sequence': 'first'},
#                                    {'affiliation': [],
#                                     'family': 'Kinnunen',
#                                     'given': 'Satu',
#                                     'sequence': 'additional'},
#                                    {'affiliation': [],
#                                     'family': 'Nevalainen',
#                                     'given': 'Jaakko',
#                                     'sequence': 'additional'},
#                                    {'affiliation': [],
#                                     'family': 'Vepsäläinen',
#                                     'given': 'Henna',
#                                     'sequence': 'additional'},
#                                    {'affiliation': [],
#                                     'family': 'Fogelholm',
#                                     'given': 'Mikael',
#                                     'sequence': 'additional'},
#                                    {'affiliation': [],
#                                     'family': 'Saarijärvi',
#                                     'given': 'Hannu',
#                                     'sequence': 'additional'},
#                                    {'affiliation': [],
#                                     'family': 'Meinilä',
#                                     'given': 'Jelena',
#                                     'sequence': 'additional'},
#                                    {'affiliation': [],
#                                     'family': 'Erkkola',
#                                     'given': 'Maijaliisa',
#                                     'sequence': 'additional'}],
#                         'container-title': ['British Journal of Nutrition'],
#                         'content-domain': {'crossmark-restriction': True,
#                                            'domain': ['cambridge.org']},
#                         'created': {'date-parts': [[2024, 10, 25]],
#                                     'date-time': '2024-10-25T07:52:42Z',
#                                     'timestamp': 1729842762000},
#                         'deposited': {'date-parts': [[2025, 3, 27]],
#                                       'date-time': '2025-03-27T06:24:40Z',
#                                       'timestamp': 1743056680000},
#                         'indexed': {'date-parts': [[2025, 3, 28]],
#                                     'date-time': '2025-03-28T04:03:21Z',
#                                     'timestamp': 1743134601758,
#                                     'version': '3.40.3'},
#                         'is-referenced-by-count': 0,
#                         'issn-type': [{'type': 'print', 'value': '0007-1145'},
#                                       {'type': 'electronic',
#                                        'value': '1475-2662'}],
#                         'issue': '6',
#                         'issued': {'date-parts': [[2024, 9, 28]]},
#                         'journal-issue': {'issue': '6',
#                                           'published-print': {'date-parts': [[2024,
#                                                                               9,
#                                                                               28]]}},
#                         'language': 'en',
#                         'license': [{'URL': 'https://www.cambridge.org/core/terms',
#                                      'content-version': 'unspecified',
#                                      'delay-in-days': 27,
#                                      'start': {'date-parts': [[2024, 10, 25]],
#                                                'date-time': '2024-10-25T00:00:00Z',
#                                                'timestamp': 1729814400000}}],
#                         'link': [{'URL': 'https://www.cambridge.org/core/services/aop-cambridge-core/content/view/S0007114524002411',
#                                   'content-type': 'unspecified',
#                                   'content-version': 'vor',
#                                   'intended-application': 'similarity-checking'}],
#                         'member': '56',
#                         'page': '782-782',
#                         'prefix': '10.1017',
#                         'published': {'date-parts': [[2024, 9, 28]]},
#                         'published-online': {'date-parts': [[2024, 10, 25]]},
#                         'published-print': {'date-parts': [[2024, 9, 28]]},
#                         'publisher': 'Cambridge University Press (CUP)',
#                         'reference-count': 0,
#                         'references-count': 0,
#                         'resource': {'primary': {'URL': 'https://www.cambridge.org/core/product/identifier/S0007114524002411/type/journal_article'}},
#                         'score': 0.0,
#                         'short-container-title': ['Br J Nutr'],
#                         'source': 'Crossref',
#                         'title': ['Building nutritionally meaningful '
#                                   'classification for grocery product groups: '
#                                   'the LoCard Food Classification process – '
#                                   'ERRATUM'],
#                         'type': 'journal-article',
#                         'update-policy': 'https://doi.org/10.1017/policypage',
#                         'update-to': [{'DOI': '10.1017/s0007114524000710',
#                                        'label': 'Correction',
#                                        'source': 'publisher',
#                                        'type': 'correction',
#                                        'updated': {'date-parts': [[2024,
#                                                                    4,
#                                                                    18]],
#                                                    'date-time': '2024-04-18T00:00:00Z',
#                                                    'timestamp': 1713398400000}}],
#                         'volume': '132'},
#                        {'DOI': '10.1007/s42360-024-00816-z',
#                         'ISSN': ['0367-973X', '2248-9800'],
#                         'URL': 'https://doi.org/10.1007/s42360-024-00816-z',
#                         'alternative-id': ['816'],
#                         'assertion': [{'group': {'label': 'Article History',
#                                                  'name': 'ArticleHistory'},
#                                        'label': 'First Online',
#                                        'name': 'first_online',
#                                        'order': 1,
#                                        'value': '16 December 2024'},
#                                       {'label': 'Free to read',
#                                        'name': 'free',
#                                        'value': 'This content has been made '
#                                                 'available to all.'}],
#                         'author': [{'ORCID': 'https://orcid.org/0000-0002-4070-8412',
#                                     'affiliation': [],
#                                     'authenticated-orcid': False,
#                                     'family': 'Bhardwaj',
#                                     'given': 'S. C.',
#                                     'sequence': 'first'}],
#                         'container-title': ['Indian Phytopathology'],
#                         'content-domain': {'crossmark-restriction': False,
#                                            'domain': ['link.springer.com']},
#                         'created': {'date-parts': [[2024, 12, 16]],
#                                     'date-time': '2024-12-16T11:12:22Z',
#                                     'timestamp': 1734347542000},
#                         'deposited': {'date-parts': [[2025, 3, 27]],
#                                       'date-time': '2025-03-27T11:03:52Z',
#                                       'timestamp': 1743073432000},
#                         'indexed': {'date-parts': [[2025, 3, 28]],
#                                     'date-time': '2025-03-28T04:05:21Z',
#                                     'timestamp': 1743134721532,
#                                     'version': '3.40.3'},
#                         'is-referenced-by-count': 0,
#                         'issn-type': [{'type': 'print', 'value': '0367-973X'},
#                                       {'type': 'electronic',
#                                        'value': '2248-9800'}],
#                         'issue': '1',
#                         'issued': {'date-parts': [[2024, 12, 16]]},
#                         'journal-issue': {'issue': '1',
#                                           'published-print': {'date-parts': [[2025,
#                                                                               3]]}},
#                         'language': 'en',
#                         'license': [{'URL': 'https://www.springernature.com/gp/researchers/text-and-data-mining',
#                                      'content-version': 'tdm',
#                                      'delay-in-days': 0,
#                                      'start': {'date-parts': [[2024, 12, 16]],
#                                                'date-time': '2024-12-16T00:00:00Z',
#                                                'timestamp': 1734307200000}},
#                                     {'URL': 'https://www.springernature.com/gp/researchers/text-and-data-mining',
#                                      'content-version': 'vor',
#                                      'delay-in-days': 0,
#                                      'start': {'date-parts': [[2024, 12, 16]],
#                                                'date-time': '2024-12-16T00:00:00Z',
#                                                'timestamp': 1734307200000}}],
#                         'link': [{'URL': 'https://link.springer.com/content/pdf/10.1007/s42360-024-00816-z.pdf',
#                                   'content-type': 'application/pdf',
#                                   'content-version': 'vor',
#                                   'intended-application': 'text-mining'},
#                                  {'URL': 'https://link.springer.com/article/10.1007/s42360-024-00816-z/fulltext.html',
#                                   'content-type': 'text/html',
#                                   'content-version': 'vor',
#                                   'intended-application': 'text-mining'},
#                                  {'URL': 'https://link.springer.com/content/pdf/10.1007/s42360-024-00816-z.pdf',
#                                   'content-type': 'application/pdf',
#                                   'content-version': 'vor',
#                                   'intended-application': 'similarity-checking'}],
#                         'member': '297',
#                         'page': '211-211',
#                         'prefix': '10.1007',
#                         'published': {'date-parts': [[2024, 12, 16]]},
#                         'published-online': {'date-parts': [[2024, 12, 16]]},
#                         'published-print': {'date-parts': [[2025, 3]]},
#                         'publisher': 'Springer Science and Business Media LLC',
#                         'reference-count': 0,
#                         'references-count': 0,
#                         'resource': {'primary': {'URL': 'https://link.springer.com/10.1007/s42360-024-00816-z'}},
#                         'score': 0.0,
#                         'short-container-title': ['Indian Phytopathology'],
#                         'source': 'Crossref',
#                         'title': ['Correction: A century of fighting wheat '
#                                   'rusts in India- lessons learnt and future '
#                                   'perspectives'],
#                         'type': 'journal-article',
#                         'update-policy': 'https://doi.org/10.1007/springer_crossmark_policy',
#                         'update-to': [{'DOI': '10.1007/s42360-024-00799-x',
#                                        'label': 'Correction',
#                                        'source': 'publisher',
#                                        'type': 'correction',
#                                        'updated': {'date-parts': [[2024,
#                                                                    12,
#                                                                    16]],
#                                                    'date-time': '2024-12-16T00:00:00Z',
#                                                    'timestamp': 1734307200000}}],
#                         'volume': '78'},
#                        {'DOI': '10.1161/str.0000000000000484',
#                         'ISSN': ['0039-2499', '1524-4628'],
#                         'URL': 'https://doi.org/10.1161/str.0000000000000484',
#                         'alternative-id': ['10.1161/STR.0000000000000484'],
#                         'assertion': [{'group': {'label': 'Publication History',
#                                                  'name': 'publication_history'},
#                                        'label': 'Published',
#                                        'name': 'published',
#                                        'order': 3,
#                                        'value': '2025-01-27'}],
#                         'container-title': ['Stroke'],
#                         'content-domain': {'crossmark-restriction': True,
#                                            'domain': ['www.ahajournals.org']},
#                         'created': {'date-parts': [[2025, 1, 27]],
#                                     'date-time': '2025-01-27T19:02:35Z',
#                                     'timestamp': 1738004555000},
#                         'deposited': {'date-parts': [[2025, 3, 27]],
#                                       'date-time': '2025-03-27T15:51:17Z',
#                                       'timestamp': 1743090677000},
#                         'indexed': {'date-parts': [[2025, 3, 28]],
#                                     'date-time': '2025-03-28T04:06:42Z',
#                                     'timestamp': 1743134802621,
#                                     'version': '3.40.3'},
#                         'is-referenced-by-count': 0,
#                         'issn-type': [{'type': 'print', 'value': '0039-2499'},
#                                       {'type': 'electronic',
#                                        'value': '1524-4628'}],
#                         'issue': '2',
#                         'issued': {'date-parts': [[2025, 2]]},
#                         'journal-issue': {'issue': '2',
#                                           'published-print': {'date-parts': [[2025,
#                                                                               2]]}},
#                         'language': 'en',
#                         'link': [{'URL': 'https://www.ahajournals.org/doi/full/10.1161/STR.0000000000000484',
#                                   'content-type': 'unspecified',
#                                   'content-version': 'vor',
#                                   'intended-application': 'similarity-checking'}],
#                         'member': '276',
#                         'prefix': '10.1161',
#                         'published': {'date-parts': [[2025, 2]]},
#                         'published-print': {'date-parts': [[2025, 2]]},
#                         'publisher': 'Ovid Technologies (Wolters Kluwer '
#                                      'Health)',
#                         'reference-count': 0,
#                         'references-count': 0,
#                         'resource': {'primary': {'URL': 'https://www.ahajournals.org/doi/10.1161/STR.0000000000000484'}},
#                         'score': 0.0,
#                         'short-container-title': ['Stroke'],
#                         'source': 'Crossref',
#                         'title': ['Correction to: Sonic Hedgehog Signaling '
#                                   'Pathway Mediates Cerebrolysin-Improved '
#                                   'Neurological Function After Stroke'],
#                         'type': 'journal-article',
#                         'update-policy': 'https://doi.org/10.1161/crossmarkpolicy',
#                         'update-to': [{'DOI': '10.1161/strokeaha.111.000831',
#                                        'label': 'Correction',
#                                        'source': 'publisher',
#                                        'type': 'correction',
#                                        'updated': {'date-parts': [[2025,
#                                                                    1,
#                                                                    27]],
#                                                    'date-time': '2025-01-27T00:00:00Z',
#                                                    'timestamp': 1737936000000}}],
#                         'volume': '56'}],
#              'items-per-page': 5,
#              'query': {'search-terms': None, 'start-index': 0},
#              'total-results': 92434},
#  'message-type': 'work-list',
#  'message-version': '1.0.0',
#  'status': 'ok'}
